# %%
# %matplotlib inline
import matplotlib.pyplot as plt
y = [1,2,3,4,5]
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
y = [13,16,15,18,16,17,16]
plt.plot(y)

# %%
y=[13,16,15,18,16,17,16]
plt.plot(range(len(y)),y);

# %%
x = ['Mon','Tue','Wed','Thur','Fri','Sat','Sun']
y = [13, 16, 15, 18, 16 ,17, 16]
plt.plot(x,y);

# %%
x = ['Mon','Tue','Wed','Thur','Fri','Sat','Sun']
y = [13, 16, 15, 18, 16 ,17, 16]
plt.plot(x,y);
plt.xlabel('Daily')
plt.ylabel('No. of Bokks Sold');

# %%
x = ['Mon','Tue','Wed','Thur','Fri','Sat','Sun']
y1 = [13, 16, 15, 18, 16 ,17, 16]
y2 = [17, 14, 17, 16, 15, 15, 14]
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel('Daily')
plt.ylabel('No. of Bokks Sold');

# %%
x = ['Mon','Tue','Wed','Thur','Fri','Sat','Sun']
y1 = [13, 16, 15, 18, 16 ,17, 16]
y2 = [17, 14, 17, 16, 15, 15, 14]
plt.plot(x,y1, label='Sold')
plt.plot(x,y2, label='On Shelves')
plt.xlabel('Daily')
plt.ylabel('No. of Bokks Sold');
plt.legend(loc="upper left")

# %%
x = ['Mon','Tue','Wed','Thur','Fri','Sat','Sun']
y1 = [13, 16, 15, 18, 16 ,17, 16]
y2 = [17, 14, 17, 16, 15, 15, 14]
plt.plot(x,y1, label='Sold')
plt.plot(x,y2, label='On Shelves')
plt.xlabel('Daily')
plt.ylabel('No. of Bokks Sold');
plt.legend(loc="upper left")
plt.title('Le Petit Prince: Sold & Left')
# Out:
# Text(0.5, 1.0, 'Le Petit Prince: Sold & Left')

# %%
import matplotlib.pyplot as plt
x=[0,1,2]
points1 = [1,2.5,3]
points2 = [3,2,1]
plt.plot(x,points1,'r-d')
plt.plot(x,points2,'k-o')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
shape = np.pi * (np.random.rand(30)*20) **2
plt.scatter(x,y, s=shape, c= colors, marker='*', alpha=0.7)
plt.show()
